# %% [markdown]
# <a href="https://colab.research.google.com/github/DostdarDost/DATA-SCIENCE-AND-ARTIFICIAL-INTELLIGENCE-DSAI-GILGIT/blob/main/CV_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install Pillow

# %%
from PIL import Image

# %%
# Imports PIL module
from PIL import Image

# open method used to open different extension image file
im = Image.open("/content/Case_a1.png")

# This method will show image in any image viewer
im.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=560x420 at 0x7F6459445360>

# %%
from PIL import ImageOps

# %%
image_gray = ImageOps.grayscale(im)
image_gray
# Out:
# <PIL.Image.Image image mode=L size=560x420 at 0x7F6459428C70>
