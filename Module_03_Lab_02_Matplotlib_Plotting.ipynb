# %% [markdown]
# <a href="https://colab.research.google.com/github/DostdarDost/DATA-SCIENCE-AND-ARTIFICIAL-INTELLIGENCE-DSAI-GILGIT/blob/main/Module_03_Lab_02_Matplotlib_Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module_03_Lab_02_Matplotlib_Plotting

# %% [markdown]
# ## 1. Bar Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
 df = pd.DataFrame(np.random.rand(6, 4),
                   index=['one', 'two', 'three', 'four', 'five', 'six'],
                   columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.177816  0.380926  0.948169  0.551040
# two    0.058018  0.877469  0.989350  0.052498
# three  0.256529  0.027343  0.532624  0.441405
# four   0.318070  0.332826  0.940490  0.887636
# five   0.070916  0.582339  0.709841  0.817573
# six    0.116286  0.922073  0.496917  0.010455

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
 df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## The Data
#
# There are some fake data csv files you can read in as dataframes:

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2')

# %% [markdown]
# ### Call the style:

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. Scatter Plots

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# ## 3. BoxPlots

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>
